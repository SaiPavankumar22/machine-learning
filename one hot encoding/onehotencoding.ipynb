# %%
import pandas as pd
df=pd.read_csv("ohc.csv")
df
# Out:
#    town  area   price
# 0   vij  2600  550000
# 1   vij  3000  565000
# 2   vij  3200  610000
# 3   vij  3600  680000
# 4   vij  4000  725000
# 5   bhi  2600  585000
# 6   bhi  2800  615000
# 7   bhi  3300  650000
# 8   bhi  3600  710000
# 9   jpt  2600  575000
# 10  jpt  2900  600000
# 11  jpt  3100  620000
# 12  jpt  3600  695000

# %%
dum=pd.get_dummies(df.town)
dum
# Out:
#       bhi    jpt    vij
# 0   False  False   True
# 1   False  False   True
# 2   False  False   True
# 3   False  False   True
# 4   False  False   True
# 5    True  False  False
# 6    True  False  False
# 7    True  False  False
# 8    True  False  False
# 9   False   True  False
# 10  False   True  False
# 11  False   True  False
# 12  False   True  False

# %%
merged = pd.concat([df,dum],axis='columns')
merged
# Out:
#    town  area   price    bhi    jpt    vij
# 0   vij  2600  550000  False  False   True
# 1   vij  3000  565000  False  False   True
# 2   vij  3200  610000  False  False   True
# 3   vij  3600  680000  False  False   True
# 4   vij  4000  725000  False  False   True
# 5   bhi  2600  585000   True  False  False
# 6   bhi  2800  615000   True  False  False
# 7   bhi  3300  650000   True  False  False
# 8   bhi  3600  710000   True  False  False
# 9   jpt  2600  575000  False   True  False
# 10  jpt  2900  600000  False   True  False
# 11  jpt  3100  620000  False   True  False
# 12  jpt  3600  695000  False   True  False

# %%
final = merged.drop(['town','vij'],axis='columns')
final
# Out:
#     area   price    bhi    jpt
# 0   2600  550000  False  False
# 1   3000  565000  False  False
# 2   3200  610000  False  False
# 3   3600  680000  False  False
# 4   4000  725000  False  False
# 5   2600  585000   True  False
# 6   2800  615000   True  False
# 7   3300  650000   True  False
# 8   3600  710000   True  False
# 9   2600  575000  False   True
# 10  2900  600000  False   True
# 11  3100  620000  False   True
# 12  3600  695000  False   True

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
x=final.drop('price',axis='columns')
x
# Out:
#     area    bhi    jpt
# 0   2600  False  False
# 1   3000  False  False
# 2   3200  False  False
# 3   3600  False  False
# 4   4000  False  False
# 5   2600   True  False
# 6   2800   True  False
# 7   3300   True  False
# 8   3600   True  False
# 9   2600  False   True
# 10  2900  False   True
# 11  3100  False   True
# 12  3600  False   True

# %%
y=final.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[3000,0,0]])
# Out:
# C:\Users\dvaru\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590468.71640507])

# %%
model.score(x,y)
# Out:
# 0.9573929037221872

# %%
df
# Out:
#    town  area   price
# 0   vij  2600  550000
# 1   vij  3000  565000
# 2   vij  3200  610000
# 3   vij  3600  680000
# 4   vij  4000  725000
# 5   bhi  2600  585000
# 6   bhi  2800  615000
# 7   bhi  3300  650000
# 8   bhi  3600  710000
# 9   jpt  2600  575000
# 10  jpt  2900  600000
# 11  jpt  3100  620000
# 12  jpt  3600  695000

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dfle = df 
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      2  2600  550000
# 1      2  3000  565000
# 2      2  3200  610000
# 3      2  3600  680000
# 4      2  4000  725000
# 5      0  2600  585000
# 6      0  2800  615000
# 7      0  3300  650000
# 8      0  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
x= dfle[['town','area']].values
x
# Out:
# array([[   2, 2600],
#        [   2, 3000],
#        [   2, 3200],
#        [   2, 3600],
#        [   2, 4000],
#        [   0, 2600],
#        [   0, 2800],
#        [   0, 3300],
#        [   0, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]], dtype=int64)

# %%
y=dfle.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("town", OneHotEncoder(), [0])], remainder = 'passthrough')
X = ct.fit_transform(X)
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from sklearn.compose import ColumnTransformer
# ----> 2 ct = ColumnTransformer([("town", OneHotEncoder(), [0])], remainder = 'passthrough')
#       3 X = ct.fit_transform(X)
#       4 X
#
# NameError: name 'OneHotEncoder' is not defined

# %%
x=x[:,1:]
x
# Out:
# array([], shape=(13, 0), dtype=int64)

# %%
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 model.fit(x,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:978, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     976     n_features = array.shape[1]
#     977     if n_features < ensure_min_features:
# --> 978         raise ValueError(
#     979             "Found array with %d feature(s) (shape=%s) while"
#     980             " a minimum of %d is required%s."
#     981             % (n_features, array.shape, ensure_min_features, context)
#     982         )
#     984 if copy:
#     985     if _is_numpy_namespace(xp):
#     986         # only make a copy if `array` and `array_orig` may share memory`
#
# ValueError: Found array with 0 feature(s) (shape=(13, 0)) while a minimum of 1 is required by LinearRegression.
